# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %%
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
# Count the number of duplicate rows
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")

# Display the first few duplicate rows
duplicate_rows = df[df.duplicated(keep=False)].sort_values(by=df.columns.tolist()).head()
print("First few duplicate rows:")
print(duplicate_rows)
# Out:
# Number of duplicate rows: 0
# First few duplicate rows:
# Empty DataFrame
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
# Identify duplicates based on selected columns
selected_columns = ['MainBranch', 'Employment', 'RemoteWork']
duplicates_subset = df[df.duplicated(subset=selected_columns, keep=False)]

# Analyze which columns frequently contain identical values
frequent_identical_columns = duplicates_subset.nunique() == 1
print("Columns with identical values in duplicate rows:")
print(frequent_identical_columns[frequent_identical_columns].index.tolist())

# Display the first few rows of duplicates based on the subset
print("First few rows of duplicates based on selected columns:")
print(duplicates_subset.sort_values(by=selected_columns).head())
# Out:
# Columns with identical values in duplicate rows:
# ['Check']
# First few rows of duplicates based on selected columns:
#     ResponseId                      MainBranch              Age  \
# 12          13  I am a developer by profession  35-44 years old
# 14          15  I am a developer by profession  25-34 years old
# 15          16  I am a developer by profession  45-54 years old
# 18          19  I am a developer by profession  25-34 years old
# 19          20  I am a developer by profession  35-44 years old
#
#              Employment                            RemoteWork   Check  \
# 12  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 14  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 15  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 18  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 19  Employed, full-time  Hybrid (some remote, some in-person)  Apples
#
# ...

# %%
# !pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
# Distribution of duplicates by Country
plt.figure(figsize=(10, 6))
sns.countplot(data=duplicates_subset, x='Country', order=duplicates_subset['Country'].value_counts().index)
plt.title("Distribution of Duplicates by Country")
plt.xticks(rotation=90)
plt.show()

# Distribution of duplicates by Employment
plt.figure(figsize=(8, 6))
sns.countplot(data=duplicates_subset, x='Employment', order=duplicates_subset['Employment'].value_counts().index)
plt.title("Distribution of Duplicates by Employment")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
# Decide critical columns for defining uniqueness
critical_columns = ['MainBranch', 'Employment', 'RemoteWork', 'Country']

# Remove duplicates based on the subset of critical columns
df_cleaned = df.drop_duplicates(subset=critical_columns)

# Verify the removal
remaining_duplicates = df_cleaned.duplicated(subset=critical_columns).sum()
print(f"Number of remaining duplicates after removal: {remaining_duplicates}")
# Out:
# Number of remaining duplicates after removal: 0

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# 1-loading the Dataset
# 2-identifying duplicate rows
# total duplicate rows 0
# 3-Analyzing Characteristics of Duplicates
# To better understand the nature of duplicates, the analysis focused on a subset of columns that are critical to defining uniqueness in the dataset. The selected columns were:
#
# MainBranch: The primary role of the respondent.
#
# Employment: The employment status of the respondent.
#
# RemoteWork: Whether the respondent works remotely.
#
# Subset-Based Duplicates: Duplicates were identified based on the selected columns using df.duplicated(subset=selected_columns, keep=False).
#
# Identical Columns: Columns that frequently contained identical values in duplicate rows were identified to understand patterns.
# 4. Visualizing the Distribution of Duplicates
# To gain insights into the distribution of duplicates, visualizations were created using matplotlib and seaborn.
#
# By Country: A bar chart was created to show the distribution of duplicates across different countries.
#
# By Employment: A bar chart was created to show the distribution of duplicates across different employment statuses.
# 5. Strategic Removal of Duplicates
# To remove duplicates, critical columns were selected to define uniqueness in the dataset. The chosen columns were:
#
# MainBranch
#
# Employment
#
# RemoteWork
#
# Country
#
# Removing Duplicates: The drop_duplicates() function was used to remove duplicates based on the selected columns.
#
# Verification: The dataset was checked to ensure no duplicates remained based on the selected columns.
# 6. Reasoning Behind Column Selection
# The columns MainBranch, Employment, RemoteWork, and Country were chosen because:
#
# They represent key attributes that define a unique respondent in the survey dataset.
#
# These columns capture the core characteristics of respondents, ensuring that duplicates are removed meaningfully without losing important data.
#
# Using these columns ensures that the dataset remains representative of unique respondents while maintaining data integrity.
#
# 7. Conclusion
# The process of identifying and removing duplicates involved:
#
# Loading the dataset.
#
# Identifying duplicate rows and analyzing their characteristics.
#
# Visualizing the distribution of duplicates.
#
# Strategically removing duplicates based on critical columns.
#
# Verifying the removal process.
#
# This ensures that the dataset is clean, consistent, and ready for further analysis. The cleaned dataset (df_cleaned) is now free of duplicates based on the selected columns, preserving the integrity and quality of the data.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
